# %%
import speech_recognition as sr
import pyttsx3

# Initialize the speech engine
engine = pyttsx3.init()

# Function to make the assistant speak
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to take voice input
def listen():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
        try:
            print("Recognizing...")
            query = recognizer.recognize_google(audio)
            print(f"You said: {query}")
            return query.lower()
        except sr.UnknownValueError:
            print("Sorry, I did not understand that.")
            speak("Sorry, I did not understand that.")
            return ""
        except sr.RequestError:
            print("Speech service is down.")
            speak("Speech service is down.")
            return ""

# Main function to run the assistant
def assistant():
    speak("Hello, I am your assistant. How can I help you?")
    while True:
        query = listen()
        if 'exit' in query or 'bye' in query:
            speak("Goodbye!")
            break
        elif 'your name' in query:
            speak("My name is Python Voice Assistant.")
        elif 'time' in query:
            from datetime import datetime
            now = datetime.now()
            current_time = now.strftime("%H:%M")
            speak(f"The current time is {current_time}")
        elif 'search' in query:
            speak("What do you want to search for?")
            search_query = listen()
            if search_query:
                speak(f"Searching for {search_query}...")
                # Here you could add code to open a browser and search online
                # using webbrowser module
        else:
            speak("Sorry, I can't do that yet.")

# Run the assistant
if __name__ == "__main__":
    assistant()
# Out:
# Listening...
# Recognizing...
# You said: hello
# Listening...
# Recognizing...
# You said: what is your name
# Listening...
# Recognizing...
# Sorry, I did not understand that.
# Listening...
# Recognizing...
# You said: exist
# Listening...
# Recognizing...
# You said: 26 November
# Listening...
# Recognizing...
# Sorry, I did not understand that.
# Listening...
# Recognizing...
# You said: hello
# Listening...
# Recognizing...
# You said: what time now
# Listening...
# Recognizing...
# You said: your name
# Listening...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 18, in listen()
#      17 recognizer.adjust_for_ambient_noise(source)
# ---> 18 audio = recognizer.listen(source)
#      19 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# OSError: [Errno -9999] Unanticipated host error
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 60
#      58 # Run the assistant
#      59 if __name__ == "__main__":
# ---> 60     assistant()
#
# Cell In[1], line 37, in assistant()
#      35 speak("Hello, I am your assistant. How can I help you?")
#      36 while True:
# ---> 37     query = listen()
#      38     if 'exit' in query or 'bye' in query:
#      39         speak("Goodbye!")
#
# Cell In[1], line 15, in listen()
#      13 def listen():
#      14     recognizer = sr.Recognizer()
# ---> 15     with sr.Microphone() as source:
#      16         print("Listening...")
#      17         recognizer.adjust_for_ambient_noise(source)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\speech_recognition\__init__.py:189, in Microphone.__exit__(self, exc_type, exc_value, traceback)
#     187 def __exit__(self, exc_type, exc_value, traceback):
#     188     try:
# --> 189         self.stream.close()
#     190     finally:
#     191         self.stream = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\speech_recognition\__init__.py:204, in Microphone.MicrophoneStream.close(self)
#     201 def close(self):
#     202     try:
#     203         # sometimes, if the stream isn't stopped, closing the stream throws an exception
# --> 204         if not self.pyaudio_stream.is_stopped():
#     205             self.pyaudio_stream.stop_stream()
#     206     finally:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyaudio\__init__.py:515, in PyAudio.Stream.is_stopped(self)
#     510 def is_stopped(self):
#     511     """Returns whether the stream is stopped.
#     512
#     513     :rtype: bool
#     514     """
# --> 515     return pa.is_stream_stopped(self._stream)
#
# OSError: [Errno -9988] Stream closed
